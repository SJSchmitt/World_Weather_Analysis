# %% [markdown]
# ## 1. Generate Random Cities
# ### Generate Random Coordinates

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from scipy.stats import linregress
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)

# %% [markdown]
# ### Find Unique Cities Based on Coordinates

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Base URL for Weather Map API Call.
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vardo
# Processing Record 2 of Set 1 | hithadhoo
# Processing Record 3 of Set 1 | bluff
# Processing Record 4 of Set 1 | kerteh
# City not found. Skipping...
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 1 | san patricio
# Processing Record 7 of Set 1 | hilo
# Processing Record 8 of Set 1 | warmbad
# Processing Record 9 of Set 1 | chokurdakh
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | bani walid
# Processing Record 12 of Set 1 | goalpara
# Processing Record 13 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | ponta do sol
# Processing Record 17 of Set 1 | kavieng
# Processing Record 18 of Set 1 | ilulissat
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | butaritari
# Processing Record 21 of Set 1 | udachnyy
# Processing Record 22 of Set 1 | guerrero negro
# Processing Record 23 of Set 1 | talara
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 1 | atuona
# Processing Record 28 of Set 1 | cockburn town
# Processing Record 29 of Set 1 | latung
# Processing Record 30 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 1 | asau
# Processing Record 32 of Set 1 | new norfolk
# Processing Record 33 of Set 1 | xuzhou
# Processing Record 34 of Set 1 | castro
# Processing Record 35 of Set 1 | cherskiy
# Processing Record 36 of Set 1 | labrea
# Processing Record 37 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 1 | sao sebastiao do paraiso
# Processing Record 39 of Set 1 | touros
# Processing Record 40 of Set 1 | flinders
# Processing Record 41 of Set 1 | mount pleasant
# Processing Record 42 of Set 1 | haines junction
# Processing Record 43 of Set 1 | dien bien
# City not found. Skipping...
# Processing Record 44 of Set 1 | busselton
# Processing Record 45 of Set 1 | tezu
# Processing Record 46 of Set 1 | provideniya
# Processing Record 47 of Set 1 | venado tuerto
# Processing Record 48 of Set 1 | dzhusaly
# City not found. Skipping...
# Processing Record 49 of Set 1 | vao
# Processing Record 50 of Set 1 | olafsvik
# Processing Record 1 of Set 2 | zhongxing
# Processing Record 2 of Set 2 | longyearbyen
# Processing Record 3 of Set 2 | bethel
# Processing Record 4 of Set 2 | walvis bay
# Processing Record 5 of Set 2 | cape town
# Processing Record 6 of Set 2 | jamestown
# Processing Record 7 of Set 2 | fortuna
# Processing Record 8 of Set 2 | pevek
# Processing Record 9 of Set 2 | gat
# Processing Record 10 of Set 2 | lagoa
# Processing Record 11 of Set 2 | beloha
# Processing Record 12 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 2 | verkhovazhye
# Processing Record 14 of Set 2 | port elizabeth
# Processing Record 15 of Set 2 | hualmay
# Processing Record 16 of Set 2 | mocorito
# Processing Record 17 of Set 2 | lebu
# Processing Record 18 of Set 2 | punta arenas
# Processing Record 19 of Set 2 | kaka
# Processing Record 20 of Set 2 | tasiilaq
# Processing Record 21 of Set 2 | sitka
# Processing Record 22 of Set 2 | hermanus
# Processing Record 23 of Set 2 | mar del plata
# Processing Record 24 of Set 2 | naples
# Processing Record 25 of Set 2 | leh
# Processing Record 26 of Set 2 | barrow
# Processing Record 27 of Set 2 | thompson
# Processing Record 28 of Set 2 | ruatoria
# City not found. Skipping...
# Processing Record 29 of Set 2 | dikson
# Processing Record 30 of Set 2 | hobart
# Processing Record 31 of Set 2 | alyangula
# Processing Record 32 of Set 2 | kodiak
# Processing Record 33 of Set 2 | karauzyak
# City not found. Skipping...
# Processing Record 34 of Set 2 | putla
# City not found. Skipping...
# Processing Record 35 of Set 2 | havoysund
# Processing Record 36 of Set 2 | aklavik
# Processing Record 37 of Set 2 | luanda
# Processing Record 38 of Set 2 | lashio
# Processing Record 39 of Set 2 | lannion
# Processing Record 40 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 2 | saint-philippe
# Processing Record 42 of Set 2 | churapcha
# Processing Record 43 of Set 2 | klaksvik
# Processing Record 44 of Set 2 | avera
# Processing Record 45 of Set 2 | fairbanks
# Processing Record 46 of Set 2 | ketchikan
# Processing Record 47 of Set 2 | lubben
# Processing Record 48 of Set 2 | iqaluit
# Processing Record 49 of Set 2 | diofior
# Processing Record 50 of Set 2 | lavrentiya
# Processing Record 1 of Set 3 | sarangani
# Processing Record 2 of Set 3 | macklin
# Processing Record 3 of Set 3 | chifeng
# Processing Record 4 of Set 3 | port alfred
# Processing Record 5 of Set 3 | ancud
# Processing Record 6 of Set 3 | saint-pierre
# Processing Record 7 of Set 3 | isangel
# Processing Record 8 of Set 3 | dubbo
# Processing Record 9 of Set 3 | opopeo
# Processing Record 10 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 3 | hami
# Processing Record 12 of Set 3 | palmer
# Processing Record 13 of Set 3 | tuktoyaktuk
# Processing Record 14 of Set 3 | grindavik
# Processing Record 15 of Set 3 | monforte de lemos
# Processing Record 16 of Set 3 | bobingen
# Processing Record 17 of Set 3 | gwadar
# Processing Record 18 of Set 3 | avarua
# Processing Record 19 of Set 3 | leningradskiy
# Processing Record 20 of Set 3 | port hedland
# Processing Record 21 of Set 3 | codrington
# Processing Record 22 of Set 3 | auki
# Processing Record 23 of Set 3 | oeiras do para
# Processing Record 24 of Set 3 | rudnogorsk
# Processing Record 25 of Set 3 | clarence town
# Processing Record 26 of Set 3 | cabo san lucas
# Processing Record 27 of Set 3 | pacifica
# Processing Record 28 of Set 3 | hasanabad
# Processing Record 29 of Set 3 | palu
# Processing Record 30 of Set 3 | kapaa
# Processing Record 31 of Set 3 | sioux lookout
# Processing Record 32 of Set 3 | ribeira grande
# Processing Record 33 of Set 3 | juifang
# City not found. Skipping...
# Processing Record 34 of Set 3 | dawson
# Processing Record 35 of Set 3 | takoradi
# Processing Record 36 of Set 3 | mae sai
# Processing Record 37 of Set 3 | bredasdorp
# Processing Record 38 of Set 3 | tarbert
# Processing Record 39 of Set 3 | jumla
# Processing Record 40 of Set 3 | carnarvon
# Processing Record 41 of Set 3 | mokhsogollokh
# Processing Record 42 of Set 3 | calama
# Processing Record 43 of Set 3 | vechelde
# Processing Record 44 of Set 3 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 45 of Set 3 | dryden
# Processing Record 46 of Set 3 | westport
# Processing Record 47 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 3 | vila velha
# Processing Record 49 of Set 3 | novikovo
# Processing Record 50 of Set 3 | aquiraz
# Processing Record 1 of Set 4 | acapulco
# Processing Record 2 of Set 4 | torbay
# Processing Record 3 of Set 4 | nome
# Processing Record 4 of Set 4 | victoria
# Processing Record 5 of Set 4 | clyde river
# Processing Record 6 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 7 of Set 4 | tuatapere
# Processing Record 8 of Set 4 | boende
# Processing Record 9 of Set 4 | luderitz
# Processing Record 10 of Set 4 | oud-beijerland
# Processing Record 11 of Set 4 | nisia floresta
# Processing Record 12 of Set 4 | saint anthony
# Processing Record 13 of Set 4 | trairi
# Processing Record 14 of Set 4 | karratha
# Processing Record 15 of Set 4 | salalah
# Processing Record 16 of Set 4 | laguna
# Processing Record 17 of Set 4 | qaanaaq
# Processing Record 18 of Set 4 | san cristobal
# Processing Record 19 of Set 4 | maghama
# City not found. Skipping...
# Processing Record 20 of Set 4 | skagastrond
# City not found. Skipping...
# Processing Record 21 of Set 4 | asyut
# Processing Record 22 of Set 4 | airai
# Processing Record 23 of Set 4 | el retorno
# Processing Record 24 of Set 4 | east london
# Processing Record 25 of Set 4 | magdalena
# Processing Record 26 of Set 4 | tessalit
# Processing Record 27 of Set 4 | iskateley
# Processing Record 28 of Set 4 | dunedin
# Processing Record 29 of Set 4 | sainte-marie
# Processing Record 30 of Set 4 | aksu
# Processing Record 31 of Set 4 | faanui
# Processing Record 32 of Set 4 | lincoln
# Processing Record 33 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 4 | yellowknife
# Processing Record 35 of Set 4 | soyo
# Processing Record 36 of Set 4 | kemptville
# Processing Record 37 of Set 4 | chuy
# Processing Record 38 of Set 4 | sindor
# Processing Record 39 of Set 4 | umm kaddadah
# Processing Record 40 of Set 4 | namibe
# Processing Record 41 of Set 4 | sorland
# Processing Record 42 of Set 4 | karla
# Processing Record 43 of Set 4 | lata
# Processing Record 44 of Set 4 | olhao
# Processing Record 45 of Set 4 | stornoway
# Processing Record 46 of Set 4 | tabora
# Processing Record 47 of Set 4 | henties bay
# Processing Record 48 of Set 4 | puerto ayora
# Processing Record 49 of Set 4 | gamba
# Processing Record 50 of Set 4 | bengkulu
# Processing Record 1 of Set 5 | champerico
# Processing Record 2 of Set 5 | bogorodskoye
# Processing Record 3 of Set 5 | trofors
# Processing Record 4 of Set 5 | sao filipe
# Processing Record 5 of Set 5 | pombas
# Processing Record 6 of Set 5 | brigantine
# Processing Record 7 of Set 5 | nanortalik
# Processing Record 8 of Set 5 | vostok
# Processing Record 9 of Set 5 | hay river
# Processing Record 10 of Set 5 | muros
# Processing Record 11 of Set 5 | pisco
# Processing Record 12 of Set 5 | sataua
# City not found. Skipping...
# Processing Record 13 of Set 5 | athabasca
# Processing Record 14 of Set 5 | gashua
# Processing Record 15 of Set 5 | senanga
# Processing Record 16 of Set 5 | mahebourg
# Processing Record 17 of Set 5 | zeya
# Processing Record 18 of Set 5 | naze
# Processing Record 19 of Set 5 | kattivakkam
# Processing Record 20 of Set 5 | kruisfontein
# Processing Record 21 of Set 5 | jaisinghnagar
# Processing Record 22 of Set 5 | saint-michel-des-saints
# Processing Record 23 of Set 5 | zaruma
# Processing Record 24 of Set 5 | guarapari
# Processing Record 25 of Set 5 | greensburg
# Processing Record 26 of Set 5 | georgetown
# Processing Record 27 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 28 of Set 5 | tairua
# Processing Record 29 of Set 5 | esil
# Processing Record 30 of Set 5 | natal
# Processing Record 31 of Set 5 | bambous virieux
# Processing Record 32 of Set 5 | revda
# Processing Record 33 of Set 5 | muncar
# Processing Record 34 of Set 5 | santa barbara
# Processing Record 35 of Set 5 | port harcourt
# Processing Record 36 of Set 5 | si racha
# Processing Record 37 of Set 5 | umm lajj
# Processing Record 38 of Set 5 | tiksi
# Processing Record 39 of Set 5 | bontang
# Processing Record 40 of Set 5 | jasa tomic
# Processing Record 41 of Set 5 | arraial do cabo
# Processing Record 42 of Set 5 | union
# Processing Record 43 of Set 5 | nikolskoye
# Processing Record 44 of Set 5 | kant
# Processing Record 45 of Set 5 | chongoyape
# Processing Record 46 of Set 5 | port keats
# Processing Record 47 of Set 5 | husavik
# Processing Record 48 of Set 5 | oranjemund
# Processing Record 49 of Set 5 | amapa
# Processing Record 50 of Set 5 | sao joao da barra
# Processing Record 1 of Set 6 | santona
# Processing Record 2 of Set 6 | mariestad
# Processing Record 3 of Set 6 | ixtapa
# Processing Record 4 of Set 6 | one hundred mile house
# City not found. Skipping...
# Processing Record 5 of Set 6 | sucre
# Processing Record 6 of Set 6 | kavarna
# Processing Record 7 of Set 6 | pajapan
# Processing Record 8 of Set 6 | ca mau
# Processing Record 9 of Set 6 | augusto correa
# Processing Record 10 of Set 6 | saint george
# Processing Record 11 of Set 6 | geresk
# City not found. Skipping...
# Processing Record 12 of Set 6 | san jose
# Processing Record 13 of Set 6 | yar-sale
# Processing Record 14 of Set 6 | chara
# Processing Record 15 of Set 6 | shawinigan
# Processing Record 16 of Set 6 | margate
# Processing Record 17 of Set 6 | carutapera
# Processing Record 18 of Set 6 | madimba
# Processing Record 19 of Set 6 | kaitangata
# Processing Record 20 of Set 6 | katherine
# Processing Record 21 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 6 | cidreira
# Processing Record 23 of Set 6 | bonham
# Processing Record 24 of Set 6 | savonlinna
# Processing Record 25 of Set 6 | kaeo
# Processing Record 26 of Set 6 | susanville
# Processing Record 27 of Set 6 | norman wells
# Processing Record 28 of Set 6 | puerto escondido
# Processing Record 29 of Set 6 | evensk
# Processing Record 30 of Set 6 | san andres
# Processing Record 31 of Set 6 | talnakh
# Processing Record 32 of Set 6 | astana
# Processing Record 33 of Set 6 | bereda
# Processing Record 34 of Set 6 | kysyl-syr
# Processing Record 35 of Set 6 | lang son
# Processing Record 36 of Set 6 | mezhdurechensk
# Processing Record 37 of Set 6 | katsuura
# Processing Record 38 of Set 6 | adre
# Processing Record 39 of Set 6 | bealanana
# Processing Record 40 of Set 6 | sjoholt
# Processing Record 41 of Set 6 | belmonte
# Processing Record 42 of Set 6 | karamay
# City not found. Skipping...
# Processing Record 43 of Set 6 | mount gambier
# Processing Record 44 of Set 6 | bihoro
# Processing Record 45 of Set 6 | sirsilla
# Processing Record 46 of Set 6 | hambantota
# Processing Record 47 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 6 | sopotu nou
# Processing Record 49 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 50 of Set 6 | jiayuguan
# Processing Record 1 of Set 7 | bubaque
# Processing Record 2 of Set 7 | porto recanati
# Processing Record 3 of Set 7 | adrar
# Processing Record 4 of Set 7 | constitucion
# Processing Record 5 of Set 7 | souillac
# Processing Record 6 of Set 7 | narsaq
# Processing Record 7 of Set 7 | anito
# Processing Record 8 of Set 7 | upernavik
# Processing Record 9 of Set 7 | puri
# Processing Record 10 of Set 7 | norwalk
# Processing Record 11 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 12 of Set 7 | novotalitsy
# City not found. Skipping...
# Processing Record 13 of Set 7 | pristina
# Processing Record 14 of Set 7 | calvinia
# Processing Record 15 of Set 7 | maceio
# Processing Record 16 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 7 | witu
# Processing Record 18 of Set 7 | vila
# Processing Record 19 of Set 7 | magadan
# Processing Record 20 of Set 7 | odugathur
# City not found. Skipping...
# Processing Record 21 of Set 7 | tabou
# Processing Record 22 of Set 7 | lima
# Processing Record 23 of Set 7 | khatanga
# Processing Record 24 of Set 7 | hasaki
# Processing Record 25 of Set 7 | ekhabi
# Processing Record 26 of Set 7 | vera cruz
# Processing Record 27 of Set 7 | goderich
# Processing Record 28 of Set 7 | merauke
# Processing Record 29 of Set 7 | jinchang
# Processing Record 30 of Set 7 | manhattan
# Processing Record 31 of Set 7 | anda
# Processing Record 32 of Set 7 | kang
# Processing Record 33 of Set 7 | hargeysa
# Processing Record 34 of Set 7 | kleck
# City not found. Skipping...
# Processing Record 35 of Set 7 | saint-jean-de-luz
# Processing Record 36 of Set 7 | severo-kurilsk
# Processing Record 37 of Set 7 | kavaratti
# Processing Record 38 of Set 7 | douglas
# Processing Record 39 of Set 7 | tigzirt
# Processing Record 40 of Set 7 | hamilton
# Processing Record 41 of Set 7 | villablino
# Processing Record 42 of Set 7 | niagara falls
# Processing Record 43 of Set 7 | lhokseumawe
# Processing Record 44 of Set 7 | samarai
# Processing Record 45 of Set 7 | atar
# Processing Record 46 of Set 7 | japura
# Processing Record 47 of Set 7 | puerto del rosario
# Processing Record 48 of Set 7 | mutoko
# Processing Record 49 of Set 7 | te anau
# Processing Record 50 of Set 7 | puerto baquerizo moreno
# Processing Record 1 of Set 8 | janakkala
# Processing Record 2 of Set 8 | ha
# City not found. Skipping...
# Processing Record 3 of Set 8 | boyuibe
# Processing Record 4 of Set 8 | saldanha
# Processing Record 5 of Set 8 | sola
# Processing Record 6 of Set 8 | faya
# Processing Record 7 of Set 8 | turayf
# Processing Record 8 of Set 8 | pangody
# Processing Record 9 of Set 8 | benguela
# Processing Record 10 of Set 8 | mogadishu
# Processing Record 11 of Set 8 | ryotsu
# Processing Record 12 of Set 8 | paamiut
# Processing Record 13 of Set 8 | mudgee
# Processing Record 14 of Set 8 | kalaleh
# Processing Record 15 of Set 8 | eenhana
# Processing Record 16 of Set 8 | porirua
# Processing Record 17 of Set 8 | macusani
# Processing Record 18 of Set 8 | papillion
# Processing Record 19 of Set 8 | zhangye
# Processing Record 20 of Set 8 | farmington
# Processing Record 21 of Set 8 | saurimo
# Processing Record 22 of Set 8 | caravelas
# Processing Record 23 of Set 8 | dubuque
# Processing Record 24 of Set 8 | tilichiki
# Processing Record 25 of Set 8 | serebryansk
# Processing Record 26 of Set 8 | raudeberg
# Processing Record 27 of Set 8 | norman
# Processing Record 28 of Set 8 | saskylakh
# Processing Record 29 of Set 8 | dudinka
# Processing Record 30 of Set 8 | mahibadhoo
# Processing Record 31 of Set 8 | liuli
# Processing Record 32 of Set 8 | kudahuvadhoo
# Processing Record 33 of Set 8 | oxapampa
# Processing Record 34 of Set 8 | the valley
# Processing Record 35 of Set 8 | mareeba
# Processing Record 36 of Set 8 | mananara
# Processing Record 37 of Set 8 | munak
# Processing Record 38 of Set 8 | kampene
# Processing Record 39 of Set 8 | riyadh
# Processing Record 40 of Set 8 | sribne
# Processing Record 41 of Set 8 | sistranda
# Processing Record 42 of Set 8 | buala
# Processing Record 43 of Set 8 | kulhudhuffushi
# Processing Record 44 of Set 8 | yenagoa
# Processing Record 45 of Set 8 | lompoc
# Processing Record 46 of Set 8 | sisimiut
# Processing Record 47 of Set 8 | concepcion de maria
# City not found. Skipping...
# Processing Record 48 of Set 8 | inderborskiy
# City not found. Skipping...
# Processing Record 49 of Set 8 | axim
# Processing Record 50 of Set 8 | keita
# Processing Record 1 of Set 9 | aykhal
# Processing Record 2 of Set 9 | manggar
# Processing Record 3 of Set 9 | gurupa
# Processing Record 4 of Set 9 | cangucu
# Processing Record 5 of Set 9 | ulaangom
# Processing Record 6 of Set 9 | urengoy
# Processing Record 7 of Set 9 | alta floresta
# Processing Record 8 of Set 9 | poso
# Processing Record 9 of Set 9 | manaus
# Processing Record 10 of Set 9 | verkhnyaya inta
# Processing Record 11 of Set 9 | port-cartier
# Processing Record 12 of Set 9 | bousse
# Processing Record 13 of Set 9 | palm coast
# Processing Record 14 of Set 9 | khilok
# Processing Record 15 of Set 9 | taoudenni
# Processing Record 16 of Set 9 | bulgan
# Processing Record 17 of Set 9 | ust-kuyga
# Processing Record 18 of Set 9 | suez
# Processing Record 19 of Set 9 | los llanos de aridane
# Processing Record 20 of Set 9 | lumeje
# Processing Record 21 of Set 9 | saint-jean-de-maurienne
# Processing Record 22 of Set 9 | broken hill
# Processing Record 23 of Set 9 | mehriz
# Processing Record 24 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 9 | shelburne
# Processing Record 26 of Set 9 | ciudad bolivar
# Processing Record 27 of Set 9 | matara
# Processing Record 28 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 29 of Set 9 | along
# Processing Record 30 of Set 9 | aasiaat
# Processing Record 31 of Set 9 | orbetello
# Processing Record 32 of Set 9 | malanje
# Processing Record 33 of Set 9 | jiroft
# City not found. Skipping...
# Processing Record 34 of Set 9 | hofn
# Processing Record 35 of Set 9 | copiapo
# Processing Record 36 of Set 9 | deputatskiy
# Processing Record 37 of Set 9 | itaituba
# Processing Record 38 of Set 9 | tagab
# Processing Record 39 of Set 9 | rocha
# Processing Record 40 of Set 9 | kavali
# Processing Record 41 of Set 9 | nikolayevka
# Processing Record 42 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 43 of Set 9 | sibolga
# Processing Record 44 of Set 9 | daoukro
# Processing Record 45 of Set 9 | salamiyah
# Processing Record 46 of Set 9 | zaraza
# Processing Record 47 of Set 9 | banjar
# Processing Record 48 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 49 of Set 9 | poum
# Processing Record 50 of Set 9 | mehamn
# Processing Record 1 of Set 10 | pousat
# City not found. Skipping...
# Processing Record 2 of Set 10 | tricase
# Processing Record 3 of Set 10 | mahajanga
# Processing Record 4 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 5 of Set 10 | sabha
# Processing Record 6 of Set 10 | kaputa
# Processing Record 7 of Set 10 | newport
# Processing Record 8 of Set 10 | dali
# Processing Record 9 of Set 10 | esperance
# Processing Record 10 of Set 10 | linhai
# Processing Record 11 of Set 10 | wewak
# Processing Record 12 of Set 10 | ranong
# Processing Record 13 of Set 10 | tiznit
# Processing Record 14 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 10 | ballitoville
# Processing Record 16 of Set 10 | santa maria
# Processing Record 17 of Set 10 | road town
# Processing Record 18 of Set 10 | micheweni
# Processing Record 19 of Set 10 | kindu
# Processing Record 20 of Set 10 | ronneby
# Processing Record 21 of Set 10 | flin flon
# Processing Record 22 of Set 10 | zemio
# Processing Record 23 of Set 10 | jaypur
# Processing Record 24 of Set 10 | beringovskiy
# Processing Record 25 of Set 10 | gidole
# Processing Record 26 of Set 10 | caarapo
# Processing Record 27 of Set 10 | yerofey pavlovich
# Processing Record 28 of Set 10 | bulungu
# Processing Record 29 of Set 10 | nenjiang
# Processing Record 30 of Set 10 | kupino
# Processing Record 31 of Set 10 | geylegphug
# City not found. Skipping...
# Processing Record 32 of Set 10 | ambon
# Processing Record 33 of Set 10 | troitskiy
# Processing Record 34 of Set 10 | skala fourkas
# Processing Record 35 of Set 10 | gornopravdinsk
# Processing Record 36 of Set 10 | kalmunai
# Processing Record 37 of Set 10 | vila franca do campo
# Processing Record 38 of Set 10 | krasnoselkup
# Processing Record 39 of Set 10 | azimur
# City not found. Skipping...
# Processing Record 40 of Set 10 | yunjinghong
# City not found. Skipping...
# Processing Record 41 of Set 10 | satuk
# Processing Record 42 of Set 10 | matucana
# Processing Record 43 of Set 10 | kamiiso
# Processing Record 44 of Set 10 | hurricane
# Processing Record 45 of Set 10 | machaneng
# Processing Record 46 of Set 10 | owen sound
# Processing Record 47 of Set 10 | scarborough
# Processing Record 48 of Set 10 | aybak
# City not found. Skipping...
# Processing Record 49 of Set 10 | dujuma
# City not found. Skipping...
# Processing Record 50 of Set 10 | jamalpur
# Processing Record 1 of Set 11 | sept-iles
# Processing Record 2 of Set 11 | mutsamudu
# City not found. Skipping...
# Processing Record 3 of Set 11 | corrales
# Processing Record 4 of Set 11 | yambio
# Processing Record 5 of Set 11 | vanimo
# Processing Record 6 of Set 11 | limoeiro do ajuru
# Processing Record 7 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 8 of Set 11 | saint-augustin
# Processing Record 9 of Set 11 | geraldton
# Processing Record 10 of Set 11 | quatre cocos
# Processing Record 11 of Set 11 | ugoofaaru
# Processing Record 12 of Set 11 | ahipara
# Processing Record 13 of Set 11 | eyl
# Processing Record 14 of Set 11 | atambua
# Processing Record 15 of Set 11 | maldonado
# Processing Record 16 of Set 11 | tommot
# Processing Record 17 of Set 11 | burns lake
# Processing Record 18 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 19 of Set 11 | grand gaube
# Processing Record 20 of Set 11 | key largo
# Processing Record 21 of Set 11 | bilibino
# Processing Record 22 of Set 11 | khorramshahr
# Processing Record 23 of Set 11 | hamza
# Processing Record 24 of Set 11 | killam
# Processing Record 25 of Set 11 | cabedelo
# Processing Record 26 of Set 11 | mackay
# Processing Record 27 of Set 11 | mandera
# Processing Record 28 of Set 11 | sao gabriel da cachoeira
# Processing Record 29 of Set 11 | svetlogorsk
# Processing Record 30 of Set 11 | zhaotong
# Processing Record 31 of Set 11 | portland
# Processing Record 32 of Set 11 | kingaroy
# Processing Record 33 of Set 11 | sredec
# City not found. Skipping...
# Processing Record 34 of Set 11 | saint-marc
# Processing Record 35 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 36 of Set 11 | novopavlovka
# Processing Record 37 of Set 11 | fort nelson
# Processing Record 38 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 11 | emerald
# Processing Record 40 of Set 11 | bulawayo
# Processing Record 41 of Set 11 | yomitan
# City not found. Skipping...
# Processing Record 42 of Set 11 | otjimbingwe
# Processing Record 43 of Set 11 | koumac
# Processing Record 44 of Set 11 | usoke
# Processing Record 45 of Set 11 | marathopolis
# City not found. Skipping...
# Processing Record 46 of Set 11 | fuerte olimpo
# Processing Record 47 of Set 11 | birjand
# Processing Record 48 of Set 11 | qeshm
# Processing Record 49 of Set 11 | christchurch
# Processing Record 50 of Set 11 | richards bay
# Processing Record 1 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 2 of Set 12 | emirdag
# Processing Record 3 of Set 12 | talcahuano
# Processing Record 4 of Set 12 | baruun-urt
# Processing Record 5 of Set 12 | bikaner
# Processing Record 6 of Set 12 | santa fe
# Processing Record 7 of Set 12 | puerto salgar
# Processing Record 8 of Set 12 | sosua
# Processing Record 9 of Set 12 | mogochin
# City not found. Skipping...
# Processing Record 10 of Set 12 | vestmannaeyjar
# Processing Record 11 of Set 12 | skegness
# Processing Record 12 of Set 12 | tautira
# Processing Record 13 of Set 12 | mendahara
# City not found. Skipping...
# Processing Record 14 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 15 of Set 12 | disraeli
# Processing Record 16 of Set 12 | makakilo city
# Processing Record 17 of Set 12 | frolishchi
# Processing Record 18 of Set 12 | falevao
# City not found. Skipping...
# Processing Record 19 of Set 12 | plettenberg bay
# Processing Record 20 of Set 12 | noumea
# Processing Record 21 of Set 12 | karia
# Processing Record 22 of Set 12 | kedrovyy
# Processing Record 23 of Set 12 | batemans bay
# Processing Record 24 of Set 12 | husum
# Processing Record 25 of Set 12 | dickinson
# Processing Record 26 of Set 12 | kahului
# Processing Record 27 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 12 | shaoyang
# Processing Record 29 of Set 12 | la ronge
# Processing Record 30 of Set 12 | tornio
# Processing Record 31 of Set 12 | aksarka
# Processing Record 32 of Set 12 | tiszacsege
# Processing Record 33 of Set 12 | bonthe
# Processing Record 34 of Set 12 | pithoragarh
# Processing Record 35 of Set 12 | egvekinot
# Processing Record 36 of Set 12 | alice springs
# Processing Record 37 of Set 12 | berlevag
# Processing Record 38 of Set 12 | kautokeino
# Processing Record 39 of Set 12 | rock springs
# Processing Record 40 of Set 12 | nayoro
# Processing Record 41 of Set 12 | parakan
# Processing Record 42 of Set 12 | kortkeros
# Processing Record 43 of Set 12 | bathsheba
# Processing Record 44 of Set 12 | sabang
# Processing Record 45 of Set 12 | sungaipenuh
# Processing Record 46 of Set 12 | meulaboh
# Processing Record 47 of Set 12 | hanzhong
# Processing Record 48 of Set 12 | pecos
# Processing Record 49 of Set 12 | hovd
# Processing Record 50 of Set 12 | kununurra
# Processing Record 1 of Set 13 | humaita
# Processing Record 2 of Set 13 | inhambane
# Processing Record 3 of Set 13 | san policarpo
# Processing Record 4 of Set 13 | ichinohe
# Processing Record 5 of Set 13 | moerai
# Processing Record 6 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 7 of Set 13 | kulu
# Processing Record 8 of Set 13 | jijiga
# Processing Record 9 of Set 13 | srednekolymsk
# Processing Record 10 of Set 13 | ouadda
# Processing Record 11 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 12 of Set 13 | kibaha
# Processing Record 13 of Set 13 | darhan
# Processing Record 14 of Set 13 | gambissara
# Processing Record 15 of Set 13 | bendigo
# Processing Record 16 of Set 13 | alofi
# Processing Record 17 of Set 13 | liaoyang
# Processing Record 18 of Set 13 | aketi
# Processing Record 19 of Set 13 | hounde
# Processing Record 20 of Set 13 | irun
# Processing Record 21 of Set 13 | jalu
# Processing Record 22 of Set 13 | necochea
# Processing Record 23 of Set 13 | meadow lake
# Processing Record 24 of Set 13 | babstovo
# Processing Record 25 of Set 13 | waingapu
# Processing Record 26 of Set 13 | pafos
# Processing Record 27 of Set 13 | voineasa
# Processing Record 28 of Set 13 | harer
# Processing Record 29 of Set 13 | kiama
# Processing Record 30 of Set 13 | maues
# Processing Record 31 of Set 13 | tabarqah
# City not found. Skipping...
# Processing Record 32 of Set 13 | palauig
# Processing Record 33 of Set 13 | kankakee
# Processing Record 34 of Set 13 | urdzhar
# City not found. Skipping...
# Processing Record 35 of Set 13 | xining
# Processing Record 36 of Set 13 | pangnirtung
# Processing Record 37 of Set 13 | yarkovo
# Processing Record 38 of Set 13 | yakeshi
# Processing Record 39 of Set 13 | pacific grove
# Processing Record 40 of Set 13 | arlit
# Processing Record 41 of Set 13 | kupang
# Processing Record 42 of Set 13 | novoagansk
# Processing Record 43 of Set 13 | north bend
# Processing Record 44 of Set 13 | springdale
# Processing Record 45 of Set 13 | pontal do parana
# Processing Record 46 of Set 13 | dingle
# Processing Record 47 of Set 13 | dharchula
# Processing Record 48 of Set 13 | chitral
# Processing Record 49 of Set 13 | san carlos
# Processing Record 50 of Set 13 | orotukan
# Processing Record 1 of Set 14 | tuy hoa
# Processing Record 2 of Set 14 | voh
# Processing Record 3 of Set 14 | santa lucia
# Processing Record 4 of Set 14 | oum hadjer
# Processing Record 5 of Set 14 | marsh harbour
# Processing Record 6 of Set 14 | westerland
# Processing Record 7 of Set 14 | batagay-alyta
# Processing Record 8 of Set 14 | zhangjiakou
# Processing Record 9 of Set 14 | mouila
# Processing Record 10 of Set 14 | mount isa
# Processing Record 11 of Set 14 | parati
# Processing Record 12 of Set 14 | mayo
# Processing Record 13 of Set 14 | sosnovo-ozerskoye
# Processing Record 14 of Set 14 | ferme-neuve
# Processing Record 15 of Set 14 | orasac
# Processing Record 16 of Set 14 | jiazi
# Processing Record 17 of Set 14 | illapel
# Processing Record 18 of Set 14 | tigil
# Processing Record 19 of Set 14 | baoqing
# Processing Record 20 of Set 14 | sayyan
# Processing Record 21 of Set 14 | iquique
# Processing Record 22 of Set 14 | berdigestyakh
# Processing Record 23 of Set 14 | camacha
# Processing Record 24 of Set 14 | mattru
# Processing Record 25 of Set 14 | sambava
# Processing Record 26 of Set 14 | fort saint james
# Processing Record 27 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 28 of Set 14 | lazaro cardenas
# Processing Record 29 of Set 14 | umm jarr
# City not found. Skipping...
# Processing Record 30 of Set 14 | callaway
# Processing Record 31 of Set 14 | bhadrachalam
# Processing Record 32 of Set 14 | tukrah
# Processing Record 33 of Set 14 | tura
# Processing Record 34 of Set 14 | marsa matruh
# Processing Record 35 of Set 14 | sumbe
# Processing Record 36 of Set 14 | burnie
# Processing Record 37 of Set 14 | prestea
# Processing Record 38 of Set 14 | providencia
# Processing Record 39 of Set 14 | accra
# Processing Record 40 of Set 14 | fare
# Processing Record 41 of Set 14 | stoyba
# City not found. Skipping...
# Processing Record 42 of Set 14 | novyy urgal
# Processing Record 43 of Set 14 | broome
# Processing Record 44 of Set 14 | tankara
# Processing Record 45 of Set 14 | honiara
# Processing Record 46 of Set 14 | taltal
# Processing Record 47 of Set 14 | camopi
# Processing Record 48 of Set 14 | noshiro
# Processing Record 49 of Set 14 | kazlu ruda
# Processing Record 50 of Set 14 | kuzovatovo
# Processing Record 1 of Set 15 | kirakira
# Processing Record 2 of Set 15 | xixiang
# Processing Record 3 of Set 15 | andenes
# Processing Record 4 of Set 15 | durango
# Processing Record 5 of Set 15 | coquimbo
# Processing Record 6 of Set 15 | aripuana
# Processing Record 7 of Set 15 | san nicolas
# Processing Record 8 of Set 15 | tambo
# Processing Record 9 of Set 15 | lorengau
# Processing Record 10 of Set 15 | cap malheureux
# Processing Record 11 of Set 15 | college
# Processing Record 12 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 13 of Set 15 | les cayes
# Processing Record 14 of Set 15 | atikokan
# Processing Record 15 of Set 15 | paraiso
# Processing Record 16 of Set 15 | marzuq
# Processing Record 17 of Set 15 | sirnak
# Processing Record 18 of Set 15 | port blair
# Processing Record 19 of Set 15 | leiyang
# Processing Record 20 of Set 15 | zdvinsk
# Processing Record 21 of Set 15 | bousso
# Processing Record 22 of Set 15 | kieta
# Processing Record 23 of Set 15 | dokka
# Processing Record 24 of Set 15 | balkhash
# Processing Record 25 of Set 15 | nexo
# Processing Record 26 of Set 15 | anadyr
# Processing Record 27 of Set 15 | nishihara
# Processing Record 28 of Set 15 | puerto asis
# Processing Record 29 of Set 15 | poladpur
# Processing Record 30 of Set 15 | dzaoudzi
# Processing Record 31 of Set 15 | moosburg
# Processing Record 32 of Set 15 | huarmey
# Processing Record 33 of Set 15 | mailani
# Processing Record 34 of Set 15 | nouakchott
# Processing Record 35 of Set 15 | shahganj
# Processing Record 36 of Set 15 | ekibastuz
# Processing Record 37 of Set 15 | biak
# Processing Record 38 of Set 15 | sao paulo de olivenca
# Processing Record 39 of Set 15 | nemuro
# Processing Record 40 of Set 15 | butte
# Processing Record 41 of Set 15 | fort-shevchenko
# Processing Record 42 of Set 15 | ewa beach
# Processing Record 43 of Set 15 | boca do acre
# Processing Record 44 of Set 15 | boo
# Processing Record 45 of Set 15 | orlik
# Processing Record 46 of Set 15 | malpe
# Processing Record 47 of Set 15 | sao francisco do sul
# Processing Record 48 of Set 15 | kisangani
# Processing Record 49 of Set 15 | tarnos
# Processing Record 50 of Set 15 | karoi
# Processing Record 1 of Set 16 | nabire
# Processing Record 2 of Set 16 | sovetsk
# Processing Record 3 of Set 16 | kraksaan
# Processing Record 4 of Set 16 | neftegorsk
# Processing Record 5 of Set 16 | menongue
# Processing Record 6 of Set 16 | bilgoraj
# Processing Record 7 of Set 16 | hokitika
# Processing Record 8 of Set 16 | kantang
# Processing Record 9 of Set 16 | wenzhou
# Processing Record 10 of Set 16 | aranos
# Processing Record 11 of Set 16 | uyemskiy
# Processing Record 12 of Set 16 | banda aceh
# Processing Record 13 of Set 16 | nelson bay
# Processing Record 14 of Set 16 | tanabe
# Processing Record 15 of Set 16 | angarsk
# Processing Record 16 of Set 16 | sobolevo
# Processing Record 17 of Set 16 | shubarshi
# Processing Record 18 of Set 16 | lexington
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Add Info to Dataframe and Convert to CSV

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df = city_data_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Vardo      NO  70.3705   31.1107     17.58        93          20
# 1     Hithadhoo      MV  -0.6000   73.0833     81.10        75         100
# 2         Bluff      NZ -46.6000  168.3333     56.01        85           6
# 3  San Patricio      US  28.0170  -97.5169     64.17        38           0
# 4          Hilo      US  19.7297 -155.0900     84.27        72           0
# 5       Warmbad      NA -28.4500   18.7333     82.17        16           0
# 6    Chokurdakh      RU  70.6333  147.9167    -24.88       100          96
# 7         Vaini      TO -21.2000 -175.2000     77.16        94          40
# 8    Bani Walid      LY  31.7566   13.9942     60.55        46           4
# 9      Goalpara      IN  26.1667   90.6167     55.26        78           0
#
#    Wind Speed Current Description
# 0       42.57          few clouds
# 1       13.67     overcast clouds
# 2        4.29           clear sky
# 3        5.75           clear sky
# 4        8.05           clear sky
# 5       15.97           clear sky
# 6        5.41     overcast clouds
# 7        2.30    scattered clouds
# 8        2.15           clear sky
# 9        4.79           clear sky

# %%
# Export the City_Data into a CSV.
output_data_file = "resources/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
