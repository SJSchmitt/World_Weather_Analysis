# %% [markdown]
# ## 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps
import numpy as np

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("resources/WeatherPy_database.csv")

# %%
# Prompt the user to enter minimum and maximum temperature criteria 
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 60
# What is the maximum temperature you would like for your trip? 85

# %%
# Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]

# %%
# Determine if there are any empty rows.
preferred_cities_df.count()
# Out:
# City_ID                347
# City                   347
# Country                339
# Lat                    347
# Lng                    347
# Max Temp               347
# Humidity               347
# Cloudiness             347
# Wind Speed             347
# Current Description    347
# dtype: int64

# %%
# Create a new DataFrame that doesn’t have empty rows.
clean_df = preferred_cities_df.dropna()

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()
# Add "Hotel Name" column
hotel_df["Hotel Name"] = np.nan
hotel_df.head(10)
# Out:
#               City Country  Max Temp Current Description      Lat       Lng  \
# 1        Hithadhoo      MV     81.10     overcast clouds  -0.6000   73.0833
# 3     San Patricio      US     64.17           clear sky  28.0170  -97.5169
# 4             Hilo      US     84.27           clear sky  19.7297 -155.0900
# 7            Vaini      TO     77.16    scattered clouds -21.2000 -175.2000
# 8       Bani Walid      LY     60.55           clear sky  31.7566   13.9942
# 10         Rikitea      PF     77.68           clear sky -23.1203 -134.9692
# 11    Ponta Do Sol      PT     67.12           clear sky  32.6667  -17.1000
# 12         Kavieng      PG     82.00       broken clouds  -2.5744  150.7967
# 15      Butaritari      KI     80.10          light rain   3.0707  172.7902
# 17  Guerrero Negro      MX     76.32           clear sky  27.9769 -114.0611
#
#     Hotel Name
# 1          NaN
# 3          NaN
# 4          NaN
# 7          NaN
# 8          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 15         NaN
# 17         NaN

# %%
# Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():
    # Get latitude and longitude from DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
    
    # add lat and lng to params
    params["location"] = f"{lat},{lng}"
    # Set up the base URL for the Google Directions API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # Make request and retrieve the JSON data from the search. 
    hotels = requests.get(base_url, params=params).json() 
    
    # Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Scoop Guest House
# Motel 6 Sinton, TX
# Hilo Hawaiian Hotel
# Keleti Beach Resort
# القطانشة ستي
# People ThankYou
# Hotel do Campo
# Nusa Island Retreat
# Isles Sunset Lodge
# Casa Laguna, Bed & Breakfast
# Hostal Oro Negro
# Ellie's Villa
# Villa Enata
# Osprey Beach Hotel
# Hotel not found... skipping.
# The Shingles Riverside Cottages
# CHACARA BAILLY
# BM Hotel
# INN NEW HORIZON
# Shellharbour Resort & Conference Centre
# Hotel Kou-Bugny
# Radisson Blu Hotel Waterfront, Cape Town
# Casa Das Faias
# Hotel not found... skipping.
# 39 On Nile Guest House
# Hotel Villa Kitzia Huacho
# Hostal Las Lilas
# Misty Waves Boutique Hotel
# Gran Hotel Mar del Plata
# St Ives Hobart Accommodation Tasmania
# Groote Eylandt Lodge
# EPIC SANA Luanda
# Le four à pain
# Souimanga Lodge
# JVL Inn and Cafeteria
# The Halyards Hotel & Spa
# Alize Plage
# Tanna Lodge
# Quality Inn Dubbo International
# Cabañas El Paraíso
# Sadaf Resort
# Paradise Inn
# The Esplanade Hotel
# Hotel not found... skipping.
# Auki Motel
# Araticu Soft Hotel
# River Downs Cottage
# Pacifica Lighthouse, Trademark Collection by Wyndham
# Hotel Santika Palu
# Sheraton Kauai Coconut Beach Resort
# Quinta da Meia Eira
# Raybow International Hotel
# Piyaporn Hill Paradise Hotel
# Bredasdorp Country Manor
# Hospitality Carnarvon
# Park Hotel Calama
# Hotel Vitória Palace
# Pousada Rua Camurupim
# Mini Central
# Ron and Tony's Bed & Breakfast
# Hotel not found... skipping.
# Rancho Crepusculo
# janelas do mar
# ibis Styles Karratha
# HAMDAN PLAZA HOTEL SALALAH, an HTG Hotel
# Pirineos
# Hotel not found... skipping.
# Tu Casa
# Samparada & Gestiada Residences
# Hotel not found... skipping.
# Scenic Hotel Southern Cross
# Les pailles en queue de Sainte Marie
# Bora-Bora Pearl Beach Resort & Spa
# Hospedaria ndozi'ame
# Nuevo Hotel Plaza
# Hotel Chik Chik Namibe
# Real Marina Residence
# Barcelona Lodge
# Finch Bay Galapagos Hotel
# Hotel not found... skipping.
# Grage Hotel Bengkulu
# Hotel Xaguate
# Paul Paradis
# Hotel San Isidro Oficial
# Forte Oil - Old Lorry Park
# Zango lodge
# Shandrani Beachcomber Resort & Spa
# Euronova Freezer
# Oyster Bay House Rental
# Hotel Zaruma Colonial
# Hotel Porto do Sol
# Cititel Penang
# Pacific Harbour Villas
# Villa Park Hotel | Natal
# Casa Tia Villa
# Zaky Homestay
# The Riviera Homes Golf Resort
# Cape Racha Hotel & Serviced Apartments
# Moon light Furnished Units
# KOPKAR Hotel Bintang Sintuk
# Pousada Porto Praia
# Hotel Caral
# Kardu Durrikardu Numida Hostel
# Hotel not found... skipping.
# Pousada Porto De Canoas
# hotel la terminal
# Hostal CasArte Takubamba
# Hotel Del Carmen
# Mường Thanh Luxury Cà Mau Hotel
# Fazenda Bacuri
# The Westin San Jose
# Lidera
# Hotel not found... skipping.
# Kaitangata Motor Camp
# Pine Tree Motel
# Hotel Castelo
# Bushido Lodge
# Aldea del Bazar Hotel and Spa
# Hotel Arena Blanca
# Hotel not found... skipping.
# Le Delta
# Pousada Monte Carmelo O Pão
# Guest rooms
# Bungalow 63
# Casa Dora, Bubaque
# Hotel not found... skipping.
# Hotel Boutique Las Azucenas
# Shanti Maurice Resort & Spa
# El Felix Cottages
# OYO 1577 Hotel Shree Hari Grand
# DoubleTree by Hilton Hotel Los Angeles - Norwalk
# Die Lemoenhuis
# Hotel Ponta Verde Maceió
# Hotel not found... skipping.
# hotêl doufoulougou
# Hotel Kamana
# Hotel not found... skipping.
# Hotel not found... skipping.
# Kang Ultra Stop
# Green leaf
# Bloc D tazoumbirt (amar)
# OYO 3278 Penginapan Alfajri
# Nuli Sapi
# Oumou Elghoura
# Rumah mbah Jamah
# Hotel JM Puerto del Rosario
# Suskwe Lodge Mutoko
# Kingsgate Hotel Te Anau
# Hotel los Algarrobos
# Residencial Eluzai
# Blue Bay Lodge
# Leumerus Bungalows
# Hotel Praia Morena
# Hotel Juba
# Parklands Resort & Conference Centre
# Amethyst Court Motor lodge (Best Price on direct bookings)
# Hotel Kawissa Saurimo
# Pousada dos Navegantes
# Omadhoo Inn
# Puulu Beach,Puulu Village
# Niyama Private Islands Maldives
# Hotel Heidinger
# CeBlue Villas & Beach Resort
# Trinity Plains Tourist Park
# Chez Roger
# Hotel not found... skipping.
# Maringe Lagoon Lodge
# Haajy Guest House 1
# Aridolf Resort Wellness and Spa
# Axim Beach Resort And Spa
# Hotel not found... skipping.
# Guest Hotel
# Hotel Vitória
# Tchê Parque
# Floresta Amazonica Hotel
# Hotel 77 Poso
# Manaus Hotéis Millennium
# Maison d'hôtes EBEN-EZER DE BOUSSE
# Hammock Beach Golf Resort & Spa
# Hotel not found... skipping.
# Valle Aridane
# Hotel not found... skipping.
# Royal Exchange Hotel
# Amaloh Boutique Resort
# Hotel Ginga
# Antay Casino Hotel
# Hotel Campos
# Hotel Arrarte
# Hotel Mourya Paradise
# Hotel Syariah CN Darussalam
# Komenan brou roseline
# Hotel Zaraza
# The Hamsa Resort
# Hotel not found... skipping.
# Hôtel Restaurant Gourmand Coco Lodge Majunga
# Chelelwa Charlets
# In Wewak Boutique Hotel
# Tinidee Hotel@Ranong
# Hotel not found... skipping.
# Hampshire Hotel-Ballito
# Hotel Morotin
# ZINGARA 76ft Catamaran, full crew-all included
# Hotel not found... skipping.
# Résidence Okanda
# OCHA Office
# Hotel Hello Jeypore
# Shallom mekaneyesus church
# Maison MC Michel
# Swiss-Belhotel Ambon
# VS Villa
# Pestana Bahia Praia
# Hostal La Fontana
# Super 8 by Wyndham Hurricane Zion National Park
# BushBabies
# College hostel
# Naivasha Hotel
# Vahmoneh Lodge Vanimo
# Hotel Dalva
# Broadwater Mariner Resort
# Sunrise Attitude Hotel
# Ungoofaaru Inn
# Ahipara Holiday Park
# EYL AQUE SYSTEM
# Ros Muskanan
# La Cimarrona
# Veranda Paul et Virginie Hotel & Spa
# Bayside Inn Key Largo
# Pousada Camboinha
# International Lodge Motel
# Alarne - Área De Lazer Do Alto Rio Negro
# Ascot Lodge Motel Kingaroy
# Maguana Hotel
# Emerald Inn
# 4 On Housman Backpackers
# Le Monitel
# Hotel not found... skipping.
# Qeshm Kavan Hotel
# The George
# BON Hotel Waterfront Richards Bay
# departamento comodo
# Hotel Confort
# Pension Oaoa
# Marriott's Ko Olina Beach Club
# Thanda Vista B&B
# Hôtel Le Lagon
# Kasakchiya Luxury Suites
# Batemans Bay Marina Resort
# Maui Seaside Hotel
# Bonthe Holiday Village
# Desert Palms Alice Springs
# Mejlis taklim Al-ikhlas
# Atlantis Hotel
# Hotel Citra
# Penginapan Citra Alam
# Kost Pria
# Knights Inn & Suites Pecos Northeast
# Hotel Kununurra
# Corrêa Hotel
# Oceano
# Agapita M. Nicart
# Le Manotel
# RAMAAS HOTEL
# Hotel not found... skipping.
# GOODJANETH GARDEN RESORT
# Hotel not found... skipping.
# The Hotel Shamrock
# Taloa Heights
# Hotel not found... skipping.
# Carrefour où ouvriers dorment
# dyd -mar Hotel
# Pondok Wisata Elim
# Amir Cultural Harari Guesthouse
# The Sebel Kiama Harbourside
# Hotel Miramar
# Villa Raphael Resort
# Case de Passage De la Prefecture
# Hotel On The Rock by Prasanthi
# Eco Hostel Residencial Bananeiras
# SEGAYA PROPERTY
# Hotel Sài Gòn-Phú Yên
# Le gîte du Koniambo
# Las Tirajanas
# Hotel not found... skipping.
# Abaco Beach Resort
# Hôtel du Lac Bleu
# ibis Styles Mt Isa Verona
# Che Lagarto Paraty
# Hotel Londres
# Backpacker`s Hostel Iquique
# Hotel Porto Santo & Spa
# Mondkor Town, Bagbo Chiefdom, Bo District
# Melrose
# HOTEL QUINTA ANTIGUA
# Holiday Inn Express & Suites Panama City-Tyndall, an IHG Hotel
# Hotel Srinidhi Residency
# Lagrota restaurant
# Beau Site
# Hotel Ritz Sumbe
# Beachfront Voyager Motor Inn
# Channel 5
# Hotel not found... skipping.
# Accra City Hotel
# Maitai Lapita Village Huahine
# Sama Non-veg Hotel, Tankara
# Heritage Park Hotel
# Residencial Karime
# La pousada
# SanBiz Lodge
# Hotel not found... skipping.
# Hotel San Juan
# Hotel not found... skipping.
# NORTHVIEW Hotel
# Lorengau Harbourside Hotel
# Pereybere Hotel & Spa
# Villa Orphee
# Hotel Rinconcito Verde
# حيد القفلة
# Welcomhotel By ITC Hotels, Port Blair - Premium Hotel Near the Airport | Idyllic Island Experience Vacation
# Hotel not found... skipping.
# Uruna Bay Retreat
# Minshuku Agaihama
# Balaji Resort
# Le Rocher
# Hotel Miramar
# HOTEL IMAN
# Penginapan Kim
# Hotel not found... skipping.
# Base Lodging
# Hotel Sri Krishna Residency
# Hotel Kontiki
# Grand Ramela Hotel
# Chikangwe Guest houses
# Hotel Nusantara I
# Asrama Hati
# Ritz Lauca
# Beachfront Hotel Hokitika
# Reng Ta Chai Boutique HomeStay
# OYO 884 Rumoh PMI Hotel
# Mantra Nelson Bay

# %%
# Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df.dropna()

# %%
clean_hotel_df.head(20)
# Out:
#                         City Country  Max Temp Current Description      Lat  \
# 1                  Hithadhoo      MV     81.10     overcast clouds  -0.6000
# 3               San Patricio      US     64.17           clear sky  28.0170
# 4                       Hilo      US     84.27           clear sky  19.7297
# 7                      Vaini      TO     77.16    scattered clouds -21.2000
# 8                 Bani Walid      LY     60.55           clear sky  31.7566
# 10                   Rikitea      PF     77.68           clear sky -23.1203
# 11              Ponta Do Sol      PT     67.12           clear sky  32.6667
# 12                   Kavieng      PG     82.00       broken clouds  -2.5744
# 15                Butaritari      KI     80.10          light rain   3.0707
# 17            Guerrero Negro      MX     76.32           clear sky  27.9769
# 18                    Talara      PE     83.16           clear sky  -4.5772
# 19                   Mataura      NZ     61.50    scattered clouds -46.1927
# 21                    Atuona      PF     77.63          light rain  -9.8000
# 22             Cockburn Town      TC     82.36    scattered clouds  21.4612
# 25               New Norfolk      AU     80.10     overcast clouds -42.7826
# 27                    Castro      BR     77.14          few clouds -24.7911
# 30  Sao Sebastiao Do Paraiso      BR     71.33       broken clouds -20.9169
# 31                    Touros      BR     80.94     overcast clouds  -5.1989
# 32                  Flinders      AU     70.38          few clouds -34.5833
# 39                       Vao      NC     78.13          light rain -22.6667
#
#          Lng                               Hotel Name
# 1    73.0833                        Scoop Guest House
# 3   -97.5169                       Motel 6 Sinton, TX
# 4  -155.0900                      Hilo Hawaiian Hotel
# 7  -175.2000                      Keleti Beach Resort
# 8    13.9942                             القطانشة ستي
# 10 -134.9692                          People ThankYou
# 11  -17.1000                           Hotel do Campo
# 12  150.7967                      Nusa Island Retreat
# 15  172.7902                       Isles Sunset Lodge
# 17 -114.0611             Casa Laguna, Bed & Breakfast
# 18  -81.2719                         Hostal Oro Negro
# 19  168.8643                            Ellie's Villa
# 21 -139.0333                              Villa Enata
# 22  -71.1419                       Osprey Beach Hotel
# 25  147.0587          The Shingles Riverside Cottages
# 27  -50.0119                           CHACARA BAILLY
# 30  -46.9914                                 BM Hotel
# 31  -35.4608                          INN NEW HORIZON
# 32  150.8552  Shellharbour Resort & Conference Centre
# 39  167.4833                          Hotel Kou-Bugny

# %%
# Export the City_Data into a csv
output_data_file = "resources/WeatherPy_vacation.csv"
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp} °F</dd>
</dl>
"""

# Get the data from each row, add it to the formatting template, and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# Add a marker layer for each city to the map. 
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
